# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Encoding Techniques
# 1.Label Encoding

# %%
df=pd.read_csv("C:\\Users\\anski\\Desktop\\kartikey_kichara\\supply_chain.csv")

# %%
df.head(4)
# Out:
#   Product type   SKU      Price  Availability  Number of products sold  \
# 0     haircare  SKU0  69.808006            55                      802
# 1     skincare  SKU1  14.843523            95                      736
# 2     haircare  SKU2  11.319683            34                        8
# 3     skincare  SKU3  61.163343            68                       83
#
#    Revenue generated Customer demographics  Stock levels  Lead times  \
# 0        8661.996792            Non-binary            58           7
# 1        7460.900065                Female            53          30
# 2        9577.749626               Unknown             1          10
# 3        7766.836426            Non-binary            23          13
#
#    Order quantities  ...  Location Lead time  Production volumes  \
# 0                96  ...    Mumbai        29                 215
# 1                37  ...    Mumbai        23                 517
# ...

# %%
df.isnull().sum()
# Out:
# Product type               0
# SKU                        0
# Price                      0
# Availability               0
# Number of products sold    0
# Revenue generated          0
# Customer demographics      0
# Stock levels               0
# Lead times                 0
# Order quantities           0
# Shipping times             0
# Shipping carriers          0
# Shipping costs             0
# Supplier name              0
# Location                   0
# Lead time                  0
# Production volumes         0
# Manufacturing lead time    0
# Manufacturing costs        0
# Inspection results         0
# Defect rates               0
# Transportation modes       0
# Routes                     0
# Costs                      0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

# %%
lb=LabelEncoder()

# %%
df['Product type'].value_counts()
# Out:
# Product type
# skincare     40
# haircare     34
# cosmetics    26
# Name: count, dtype: int64

# %%
df['Product type']=lb.fit_transform(df['Product type'])
df.head(3)
# Out:
#    Product type   SKU      Price  Availability  Number of products sold  \
# 0             1  SKU0  69.808006            55                      802
# 1             2  SKU1  14.843523            95                      736
# 2             1  SKU2  11.319683            34                        8
#
#    Revenue generated Customer demographics  Stock levels  Lead times  \
# 0        8661.996792            Non-binary            58           7
# 1        7460.900065                Female            53          30
# 2        9577.749626               Unknown             1          10
#
#    Order quantities  ...  Location Lead time  Production volumes  \
# 0                96  ...    Mumbai        29                 215
# 1                37  ...    Mumbai        23                 517
# 2                88  ...    Mumbai        12                 971
#
#   Manufacturing lead time Manufacturing costs  Inspection results  \
# ...

# %%
df['SKU'].value_counts()
# Out:
# SKU
# SKU0     1
# SKU63    1
# SKU73    1
# SKU72    1
# SKU71    1
#         ..
# SKU30    1
# SKU29    1
# SKU28    1
# SKU27    1
# SKU99    1
# Name: count, Length: 100, dtype: int64

# %%
df['Customer demographics'].value_counts()
# Out:
# Customer demographics
# Unknown       31
# Female        25
# Non-binary    23
# Male          21
# Name: count, dtype: int64

# %%
df['Customer demographics']=lb.fit_transform(df['Customer demographics'])
df.head(5)
# Out:
#    Product type   SKU      Price  Availability  Number of products sold  \
# 0             1  SKU0  69.808006            55                      802
# 1             2  SKU1  14.843523            95                      736
# 2             1  SKU2  11.319683            34                        8
# 3             2  SKU3  61.163343            68                       83
# 4             2  SKU4   4.805496            26                      871
#
#    Revenue generated  Customer demographics  Stock levels  Lead times  \
# 0        8661.996792                      2            58           7
# 1        7460.900065                      0            53          30
# 2        9577.749626                      3             1          10
# 3        7766.836426                      2            23          13
# 4        2686.505152                      2             5           3
#
#    Order quantities  ...  Location Lead time  Production volumes  \
# ...

# %%
df['Location']=lb.fit_transform(df['Location'])
df.head(4)
# Out:
#    Product type   SKU      Price  Availability  Number of products sold  \
# 0             1  SKU0  69.808006            55                      802
# 1             2  SKU1  14.843523            95                      736
# 2             1  SKU2  11.319683            34                        8
# 3             2  SKU3  61.163343            68                       83
#
#    Revenue generated  Customer demographics  Stock levels  Lead times  \
# 0        8661.996792                      2            58           7
# 1        7460.900065                      0            53          30
# 2        9577.749626                      3             1          10
# 3        7766.836426                      2            23          13
#
#    Order quantities  ...  Location Lead time  Production volumes  \
# 0                96  ...         4        29                 215
# 1                37  ...         4        23                 517
# ...

# %%
df['Inspection results']=lb.fit_transform(df['Inspection results'])
df.head(4)
# Out:
#    Product type   SKU      Price  Availability  Number of products sold  \
# 0             1  SKU0  69.808006            55                      802
# 1             2  SKU1  14.843523            95                      736
# 2             1  SKU2  11.319683            34                        8
# 3             2  SKU3  61.163343            68                       83
#
#    Revenue generated  Customer demographics  Stock levels  Lead times  \
# 0        8661.996792                      2            58           7
# 1        7460.900065                      0            53          30
# 2        9577.749626                      3             1          10
# 3        7766.836426                      2            23          13
#
#    Order quantities  ...  Location Lead time  Production volumes  \
# 0                96  ...         4        29                 215
# 1                37  ...         4        23                 517
# ...

# %%
df['Transportation modes']=lb.fit_transform(df['Transportation modes'])
df.head(4)
# Out:
#    Product type   SKU      Price  Availability  Number of products sold  \
# 0             1  SKU0  69.808006            55                      802
# 1             2  SKU1  14.843523            95                      736
# 2             1  SKU2  11.319683            34                        8
# 3             2  SKU3  61.163343            68                       83
#
#    Revenue generated  Customer demographics  Stock levels  Lead times  \
# 0        8661.996792                      2            58           7
# 1        7460.900065                      0            53          30
# 2        9577.749626                      3             1          10
# 3        7766.836426                      2            23          13
#
#    Order quantities  ...  Location Lead time  Production volumes  \
# 0                96  ...         4        29                 215
# 1                37  ...         4        23                 517
# ...

# %%
df['Routes']=lb.fit_transform(df['Routes'])
df.head(4)
# Out:
#    Product type   SKU      Price  Availability  Number of products sold  \
# 0             1  SKU0  69.808006            55                      802
# 1             2  SKU1  14.843523            95                      736
# 2             1  SKU2  11.319683            34                        8
# 3             2  SKU3  61.163343            68                       83
#
#    Revenue generated  Customer demographics  Stock levels  Lead times  \
# 0        8661.996792                      2            58           7
# 1        7460.900065                      0            53          30
# 2        9577.749626                      3             1          10
# 3        7766.836426                      2            23          13
#
#    Order quantities  ...  Location Lead time  Production volumes  \
# 0                96  ...         4        29                 215
# 1                37  ...         4        23                 517
# ...

# %%
df['SKU']=lb.fit_transform(df['SKU'])

# %%
df.head(4)
# Out:
#    Product type  SKU      Price  Availability  Number of products sold  \
# 0             1    0  69.808006            55                      802
# 1             2    1  14.843523            95                      736
# 2             1   12  11.319683            34                        8
# 3             2   23  61.163343            68                       83
#
#    Revenue generated  Customer demographics  Stock levels  Lead times  \
# 0        8661.996792                      2            58           7
# 1        7460.900065                      0            53          30
# 2        9577.749626                      3             1          10
# 3        7766.836426                      2            23          13
#
#    Order quantities  ...  Location Lead time  Production volumes  \
# 0                96  ...         4        29                 215
# 1                37  ...         4        23                 517
# ...

# %% [markdown]
# # Get_dummies

# %%
a=pd.read_csv("C:\\Users\\anski\\Desktop\\kartikey_kichara\\supply_chain.csv")

# %%
a.head(4)
# Out:
#   Product type   SKU      Price  Availability  Number of products sold  \
# 0     haircare  SKU0  69.808006            55                      802
# 1     skincare  SKU1  14.843523            95                      736
# 2     haircare  SKU2  11.319683            34                        8
# 3     skincare  SKU3  61.163343            68                       83
#
#    Revenue generated Customer demographics  Stock levels  Lead times  \
# 0        8661.996792            Non-binary            58           7
# 1        7460.900065                Female            53          30
# 2        9577.749626               Unknown             1          10
# 3        7766.836426            Non-binary            23          13
#
#    Order quantities  ...  Location Lead time  Production volumes  \
# 0                96  ...    Mumbai        29                 215
# 1                37  ...    Mumbai        23                 517
# ...

# %%
a= pd.get_dummies(df , columns =  ['Product type', 'SKU', 'Customer demographics', 'Shipping carriers',
       'Supplier name', 'Location', 'Inspection results',
       'Transportation modes', 'Routes'],drop_first=True)

# %%
a=a.dropna()
a.head()
# Out:
#        Price  Availability  Number of products sold  Revenue generated  \
# 0  69.808006            55                      802        8661.996792
# 1  14.843523            95                      736        7460.900065
# 2  11.319683            34                        8        9577.749626
# 3  61.163343            68                       83        7766.836426
# 4   4.805496            26                      871        2686.505152
#
#    Stock levels  Lead times  Order quantities  Shipping times  Shipping costs  \
# 0            58           7                96               4        2.956572
# 1            53          30                37               2        9.716575
# 2             1          10                88               2        8.054479
# 3            23          13                59               6        1.729569
# 4             5           3                56               8        3.890548
#
# ...

# %%
b=a.astype(int)
b
# Out:
#     Price  Availability  Number of products sold  Revenue generated  \
# 0      69            55                      802               8661
# 1      14            95                      736               7460
# 2      11            34                        8               9577
# 3      61            68                       83               7766
# 4       4            26                      871               2686
# ..    ...           ...                      ...                ...
# 95     77            65                      672               7386
# 96     24            29                      324               7698
# 97      3            56                       62               4370
# 98     19            43                      913               8525
# 99     68            17                      627               9185
#
#     Stock levels  Lead times  Order quantities  Shipping times  \
# 0             58           7                96               4
# ...

# %%
df=a.copy()

# %%
x=df.drop(columns=['Routes_2'])

# %%
y=df['Routes_2']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test=train_test_split(x,y,test_size=0.2 ,random_state=42)

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc=StandardScaler()

# %%
x_train_sc=sc.fit_transform(x_train)

# %%
x_train_new = pd.DataFrame(x_train_sc , columns = x_train.columns)
np.round(x_train_new.describe() , 2)
# Out:
#        Price  Availability  Number of products sold  Revenue generated  \
# count  80.00         80.00                    80.00              80.00
# mean    0.00         -0.00                     0.00               0.00
# std     1.01          1.01                     1.01               1.01
# min    -1.51         -1.57                    -1.48              -1.77
# 25%    -0.97         -0.92                    -0.97              -1.07
# 50%     0.05         -0.03                    -0.14               0.10
# 75%     0.90          0.92                     0.83               0.89
# max     1.52          1.60                     1.78               1.50
#
#        Stock levels  Lead times  Order quantities  Shipping times  \
# count         80.00       80.00             80.00           80.00
# mean          -0.00        0.00              0.00           -0.00
# std            1.01        1.01              1.01            1.01
# ...

# %%
np.round(x_train.describe() , 2)
# Out:
#        Price  Availability  Number of products sold  Revenue generated  \
# count  80.00         80.00                    80.00              80.00
# mean   50.38         49.91                   453.20            5822.07
# std    32.40         31.45                   301.96            2704.44
# min     1.70          1.00                     8.00            1061.62
# 25%    19.07         21.25                   161.00            2938.96
# 50%    52.05         49.00                   410.00            6093.98
# 75%    79.37         78.75                   701.75            8214.98
# max    99.17        100.00                   987.00            9866.47
#
#        Stock levels  Lead times  Order quantities  Shipping times  \
# count         80.00       80.00             80.00           80.00
# mean          47.51       15.88             47.49            5.76
# std           30.81        8.67             26.90            2.78
# ...

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
mn=MinMaxScaler()

# %%
x_train_mn=mn.fit_transform(x_train)

# %%
x_train_new=pd.DataFrame(x_train_mn, columns=x_train.columns)

# %%
np.round(x_train_new.describe(),2)
# Out:
#        Price  Availability  Number of products sold  Revenue generated  \
# count  80.00         80.00                    80.00              80.00
# mean    0.50          0.49                     0.45               0.54
# std     0.33          0.32                     0.31               0.31
# min     0.00          0.00                     0.00               0.00
# 25%     0.18          0.20                     0.16               0.21
# 50%     0.52          0.48                     0.41               0.57
# 75%     0.80          0.79                     0.71               0.81
# max     1.00          1.00                     1.00               1.00
#
#        Stock levels  Lead times  Order quantities  Shipping times  \
# count         80.00       80.00             80.00           80.00
# mean           0.48        0.51              0.50            0.53
# std            0.31        0.30              0.29            0.31
# ...

# %%
df=pd.read_csv("C:\\Users\\anski\\Desktop\\kartikey_kichara\\supply_chain.csv")

# %%
df.head(4)
# Out:
#   Product type   SKU      Price  Availability  Number of products sold  \
# 0     haircare  SKU0  69.808006            55                      802
# 1     skincare  SKU1  14.843523            95                      736
# 2     haircare  SKU2  11.319683            34                        8
# 3     skincare  SKU3  61.163343            68                       83
#
#    Revenue generated Customer demographics  Stock levels  Lead times  \
# 0        8661.996792            Non-binary            58           7
# 1        7460.900065                Female            53          30
# 2        9577.749626               Unknown             1          10
# 3        7766.836426            Non-binary            23          13
#
#    Order quantities  ...  Location Lead time  Production volumes  \
# 0                96  ...    Mumbai        29                 215
# 1                37  ...    Mumbai        23                 517
# ...

# %%
from  sklearn.preprocessing import LabelEncoder

# %%
lb=LabelEncoder()

# %%
df['Product type']=lb.fit_transform(df['Product type'])

# %%
df.head(4)
# Out:
#    Product type   SKU      Price  Availability  Number of products sold  \
# 0             1  SKU0  69.808006            55                      802
# 1             2  SKU1  14.843523            95                      736
# 2             1  SKU2  11.319683            34                        8
# 3             2  SKU3  61.163343            68                       83
#
#    Revenue generated Customer demographics  Stock levels  Lead times  \
# 0        8661.996792            Non-binary            58           7
# 1        7460.900065                Female            53          30
# 2        9577.749626               Unknown             1          10
# 3        7766.836426            Non-binary            23          13
#
#    Order quantities  ...  Location Lead time  Production volumes  \
# 0                96  ...    Mumbai        29                 215
# 1                37  ...    Mumbai        23                 517
# ...

# %%
df['SKU']=lb.fit_transform(df['SKU'])

# %%
df['Customer demographics']=lb.fit_transform(df['Customer demographics'])
df['Location']=lb.fit_transform(df['Location'])
df['Inspection results']=lb.fit_transform(df['Inspection results'])
df['Transportation modes']=lb.fit_transform(df['Transportation modes'])
df['Routes']=lb.fit_transform(df['Routes'])

# %%
df.head(4)
# Out:
#    Product type  SKU      Price  Availability  Number of products sold  \
# 0             1    0  69.808006            55                      802
# 1             2    1  14.843523            95                      736
# 2             1   12  11.319683            34                        8
# 3             2   23  61.163343            68                       83
#
#    Revenue generated  Customer demographics  Stock levels  Lead times  \
# 0        8661.996792                      2            58           7
# 1        7460.900065                      0            53          30
# 2        9577.749626                      3             1          10
# 3        7766.836426                      2            23          13
#
#    Order quantities  ...  Location Lead time  Production volumes  \
# 0                96  ...         4        29                 215
# 1                37  ...         4        23                 517
# ...

# %%
a=df.copy()

# %%
a
# Out:
#     Product type  SKU      Price  Availability  Number of products sold  \
# 0              1    0  69.808006            55                      802
# 1              2    1  14.843523            95                      736
# 2              1   12  11.319683            34                        8
# 3              2   23  61.163343            68                       83
# 4              2   34   4.805496            26                      871
# ..           ...  ...        ...           ...                      ...
# 95             1   95  77.903927            65                      672
# 96             0   96  24.423131            29                      324
# 97             1   97   3.526111            56                       62
# 98             2   98  19.754605            43                      913
# 99             1   99  68.517833            17                      627
#
#     Revenue generated  Customer demographics  Stock levels  Lead times  \
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 a=a.astype(int)
#       2 a
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:6534, in NDFrame.astype(self, dtype, copy, errors)
#    6530     results = [ser.astype(dtype, copy=copy) for _, ser in self.items()]
#    6532 else:
#    6533     # else, only a single dtype is given
# -> 6534     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6535     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6536     return res.__finalize__(self, method="astype")
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:414, in BaseBlockManager.astype(self, dtype, copy, errors)
#     411 elif using_copy_on_write():
#     412     copy = False
# --> 414 return self.apply(
#     415     "astype",
#     416     dtype=dtype,
#     417     copy=copy,
# ...

# %%
a.head(4)

# %%
a=pd.read_csv("C:\\Users\\anski\\Desktop\\kartikey_kichara\\supply_chain.csv")

# %%
a.head()
# Out:
#   Product type   SKU      Price  Availability  Number of products sold  \
# 0     haircare  SKU0  69.808006            55                      802
# 1     skincare  SKU1  14.843523            95                      736
# 2     haircare  SKU2  11.319683            34                        8
# 3     skincare  SKU3  61.163343            68                       83
# 4     skincare  SKU4   4.805496            26                      871
#
#    Revenue generated Customer demographics  Stock levels  Lead times  \
# 0        8661.996792            Non-binary            58           7
# 1        7460.900065                Female            53          30
# 2        9577.749626               Unknown             1          10
# 3        7766.836426            Non-binary            23          13
# 4        2686.505152            Non-binary             5           3
#
#    Order quantities  ...  Location Lead time  Production volumes  \
# ...

# %%
a=pd.get_dummies(df,columns=['Product type','SKU','Customer demographics', 'Location','Inspection results'
                        ,'Transportation modes','Routes'],drop_first=True)

# %%
# Out:
#         Price  Availability  Number of products sold  Revenue generated  \
# 0   69.808006            55                      802        8661.996792
# 1   14.843523            95                      736        7460.900065
# 2   11.319683            34                        8        9577.749626
# 3   61.163343            68                       83        7766.836426
# 4    4.805496            26                      871        2686.505152
# ..        ...           ...                      ...                ...
# 95  77.903927            65                      672        7386.363944
# 96  24.423131            29                      324        7698.424766
# 97   3.526111            56                       62        4370.916580
# 98  19.754605            43                      913        8525.952560
# 99  68.517833            17                      627        9185.185829
#
#     Stock levels  Lead times  Order quantities  Shipping times  \
# ...

# %%
a=a.drop(columns=['Shipping carriers'])

# %%
a.head()
# Out:
#        Price  Availability  Number of products sold  Revenue generated  \
# 0  69.808006            55                      802        8661.996792
# 1  14.843523            95                      736        7460.900065
# 2  11.319683            34                        8        9577.749626
# 3  61.163343            68                       83        7766.836426
# 4   4.805496            26                      871        2686.505152
#
#    Stock levels  Lead times  Order quantities  Shipping times  Shipping costs  \
# 0            58           7                96               4        2.956572
# 1            53          30                37               2        9.716575
# 2             1          10                88               2        8.054479
# 3            23          13                59               6        1.729569
# 4             5           3                56               8        3.890548
#
#   Supplier name  ...  Location_2  Location_3  Location_4  \
# ...

# %%
b=a.astype(int)
b
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[60], line 1
# ----> 1 b=a.astype(int)
#       2 b
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:6534, in NDFrame.astype(self, dtype, copy, errors)
#    6530     results = [ser.astype(dtype, copy=copy) for _, ser in self.items()]
#    6532 else:
#    6533     # else, only a single dtype is given
# -> 6534     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6535     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6536     return res.__finalize__(self, method="astype")
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:414, in BaseBlockManager.astype(self, dtype, copy, errors)
#     411 elif using_copy_on_write():
#     412     copy = False
# --> 414 return self.apply(
#     415     "astype",
#     416     dtype=dtype,
#     417     copy=copy,
# ...

# %%
a=a.drop(columns=['Supplier name'])

# %%
b=a.astype(int)
b
# Out:
#     Price  Availability  Number of products sold  Revenue generated  \
# 0      69            55                      802               8661
# 1      14            95                      736               7460
# 2      11            34                        8               9577
# 3      61            68                       83               7766
# 4       4            26                      871               2686
# ..    ...           ...                      ...                ...
# 95     77            65                      672               7386
# 96     24            29                      324               7698
# 97      3            56                       62               4370
# 98     19            43                      913               8525
# 99     68            17                      627               9185
#
#     Stock levels  Lead times  Order quantities  Shipping times  \
# 0             58           7                96               4
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
df=b.copy()

# %%
x=df.drop(columns=['Routes_2'])
y=df['Routes_2']

# %%
x_train, x_test, y_train, y_test=train_test_split(x,y,test_size=0.2 ,random_state=42)

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc=StandardScaler()

# %%
x_train_sc=sc.fit_transform(x_train)

# %%
x_train_new=pd.DataFrame(x_train_sc, columns=x_train.columns)

# %%
np.round(x_train_new.describe(),2)
# Out:
#        Price  Availability  Number of products sold  Revenue generated  \
# count  80.00         80.00                    80.00              80.00
# mean    0.00         -0.00                     0.00               0.00
# std     1.01          1.01                     1.01               1.01
# min    -1.51         -1.57                    -1.48              -1.77
# 25%    -0.97         -0.92                    -0.97              -1.07
# 50%     0.05         -0.03                    -0.14               0.10
# 75%     0.90          0.92                     0.83               0.89
# max     1.52          1.60                     1.78               1.50
#
#        Stock levels  Lead times  Order quantities  Shipping times  \
# count         80.00       80.00             80.00           80.00
# mean          -0.00        0.00              0.00           -0.00
# std            1.01        1.01              1.01            1.01
# ...

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
mn=MinMaxScaler()

# %%
x_train_mn=mn.fit_transform(x_train)

# %%
x_train_mn_new=pd.DataFrame(x_train_mn,columns=x_train.columns)

# %%
np.round(x_train_mn_new.describe(),2)
# Out:
#        Price  Availability  Number of products sold  Revenue generated  \
# count  80.00         80.00                    80.00              80.00
# mean    0.50          0.49                     0.45               0.54
# std     0.33          0.32                     0.31               0.31
# min     0.00          0.00                     0.00               0.00
# 25%     0.18          0.20                     0.16               0.21
# 50%     0.52          0.48                     0.41               0.57
# 75%     0.80          0.79                     0.71               0.81
# max     1.00          1.00                     1.00               1.00
#
#        Stock levels  Lead times  Order quantities  Shipping times  \
# count         80.00       80.00             80.00           80.00
# mean           0.48        0.51              0.50            0.53
# std            0.31        0.30              0.29            0.31
# ...

# %% [markdown]
# # ordinal encoding

# %%
df=pd.read_csv("
